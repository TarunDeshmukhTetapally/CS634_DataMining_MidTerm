# %%
# !pip install mlxtend pyfpgrowth pandas
# Out:
# Requirement already satisfied: mlxtend in /Users/komalagrawal/.virtualenvs/python3_vir/lib/python3.9/site-packages (0.23.1)
# Requirement already satisfied: pyfpgrowth in /Users/komalagrawal/.virtualenvs/python3_vir/lib/python3.9/site-packages (1.0)
# Requirement already satisfied: pandas in /Users/komalagrawal/.virtualenvs/python3_vir/lib/python3.9/site-packages (2.2.1)
# Requirement already satisfied: matplotlib>=3.0.0 in /Users/komalagrawal/.virtualenvs/python3_vir/lib/python3.9/site-packages (from mlxtend) (3.8.3)
# Requirement already satisfied: joblib>=0.13.2 in /Users/komalagrawal/.virtualenvs/python3_vir/lib/python3.9/site-packages (from mlxtend) (1.3.2)
# Requirement already satisfied: scikit-learn>=1.0.2 in /Users/komalagrawal/.virtualenvs/python3_vir/lib/python3.9/site-packages (from mlxtend) (1.4.1.post1)
# Requirement already satisfied: scipy>=1.2.1 in /Users/komalagrawal/.virtualenvs/python3_vir/lib/python3.9/site-packages (from mlxtend) (1.12.0)
# Requirement already satisfied: numpy>=1.16.2 in /Users/komalagrawal/.virtualenvs/python3_vir/lib/python3.9/site-packages (from mlxtend) (1.26.4)
# Requirement already satisfied: tzdata>=2022.7 in /Users/komalagrawal/.virtualenvs/python3_vir/lib/python3.9/site-packages (from pandas) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in /Users/komalagrawal/.virtualenvs/python3_vir/lib/python3.9/site-packages (from pandas) (2024.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/komalagrawal/.virtualenvs/python3_vir/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/komalagrawal/.virtualenvs/python3_vir/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend) (6.1.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/komalagrawal/.virtualenvs/python3_vir/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend) (3.1.1)
# Requirement already satisfied: cycler>=0.10 in /Users/komalagrawal/.virtualenvs/python3_vir/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/komalagrawal/.virtualenvs/python3_vir/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend) (4.49.0)
# Requirement already satisfied: packaging>=20.0 in /Users/komalagrawal/.virtualenvs/python3_vir/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend) (23.2)
# Requirement already satisfied: pillow>=8 in /Users/komalagrawal/.virtualenvs/python3_vir/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend) (10.2.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/komalagrawal/.virtualenvs/python3_vir/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.5)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/komalagrawal/.virtualenvs/python3_vir/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend) (1.2.0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/komalagrawal/.virtualenvs/python3_vir/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.0.0->mlxtend) (3.17.0)
# Requirement already satisfied: six>=1.5 in /Users/komalagrawal/.virtualenvs/python3_vir/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/komalagrawal/.virtualenvs/python3_vir/lib/python3.9/site-packages (from scikit-learn>=1.0.2->mlxtend) (3.3.0)
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the '/Users/komalagrawal/.virtualenvs/python3_vir/bin/python3 -m pip install --upgrade pip' command.

# %%
from csv import reader
from collections import defaultdict
from itertools import combinations, chain
from mlxtend.frequent_patterns import apriori, association_rules
from mlxtend.preprocessing import TransactionEncoder
import pandas as pd
import pyfpgrowth
import time

# %%
def run_apriori():
    dataset_choice = input("choose dataset ( amazon, bestbuy, kmart, nike, generic): ")
    # User input for minimum support and confidence
    support = float(input("Enter minimum support: "))
    confidence = float(input("Enter minimum confidence: "))
    # Reading the file and initializing sets
    with open(dataset_choice + "_transactions.csv", 'r') as file:
        csv_reader = reader(file)
        item_set = set()
        item_sets = []
        for line in csv_reader:
            cleaned_line = [value for value in line if value]
            record_set = set(cleaned_line)
            for item in record_set:
                item_set.add(frozenset([item]))
            item_sets.append(record_set)
    
    start_time_brute_force = time.time()
    
    # Initializing variables for the main algorithm
    global_freq_item_set = dict()
    global_item_set_with_sup = defaultdict(int)
    
    # getting items above minimum support
    freq_item_set = set()
    local_item_set_with_sup = defaultdict(int)
    
    for item in item_set:
        for item_set in item_sets:
            if item.issubset(item_set):
                global_item_set_with_sup[item] += 1
                local_item_set_with_sup[item] += 1
    
    for item, sup_count in local_item_set_with_sup.items():
        support_value = float(sup_count / len(item_sets))
        if support_value >= support:
            freq_item_set.add(item)
    
    L1_item_set = freq_item_set
    current_lset = L1_item_set
    k = 2
    
    while current_lset:
        global_freq_item_set[k - 1] = current_lset
        # Self-joining Lk
        candidate_set = set([i.union(j) for i in current_lset for j in current_lset if len(i.union(j)) == k])
    
        # Pruning
        temp_candidate_set = candidate_set.copy()
        for item in candidate_set:
            subsets = combinations(item, k - 1)
            for subset in subsets:
                if frozenset(subset) not in current_lset:
                    temp_candidate_set.remove(item)
                    break
        candidate_set = temp_candidate_set
    
        # Counting support again
        current_lset = set()
        local_item_set_with_sup = defaultdict(int)
        for item in candidate_set:
            for item_set in item_sets:
                if item.issubset(item_set):
                    global_item_set_with_sup[item] += 1
                    local_item_set_with_sup[item] += 1
    
        for item, sup_count in local_item_set_with_sup.items():
            support_value = float(sup_count / len(item_sets))
            if support_value >= support:
                current_lset.add(item)
        k += 1
    
    # Association rule generation
    rules = []
    for k, item_set in global_freq_item_set.items():
        for item in item_set:
            subsets = chain.from_iterable(combinations(item, r) for r in range(1, len(item)))
            for s in subsets:
                confidence_value = float(global_item_set_with_sup[item] / global_item_set_with_sup[frozenset(s)])
                if confidence_value > confidence:
                    rules.append([set(s), set(item.difference(s)), confidence_value])
    
    rules.sort(key=lambda x: x[2])
    
    end_time_brute_force = time.time()
    print(f"Brute-Force Time: {end_time_brute_force - start_time_brute_force} seconds")
    # Printing the results
    print("Frequent item sets")
    print(global_freq_item_set)
    
    print("Associated Rules:")
    for rule in rules:
        print(rule)
    
    print("--Applying Apriori Algo from a python library--")
    # Apriori Alogirm from mlxtend
    # Preprocess data for mlxtend
    start_time_apriori = time.time()
    te = TransactionEncoder()
    te_ary = te.fit(item_sets).transform(item_sets)
    df = pd.DataFrame(te_ary, columns=te.columns_)
    
    # Apply Apriori
    frequent_item_sets_apriori = apriori(df, min_support=support, use_colnames=True)
    
    # Generate rules
    rules_apriori = association_rules(frequent_item_sets_apriori, metric="confidence", min_threshold=confidence)
    end_time_apriori = time.time()
    print(f"Apriori Time: {end_time_apriori - start_time_apriori} seconds")
    
    # Print Apriori generated rules
    print("Apriori Rules")
    print(rules_apriori[['antecedents', 'consequents', 'support', 'confidence']])
    
    
    print("--Applying FP-Growth Algorith--")
    # FP growth algos
    # Find frequent patterns
    start_time_fpgrowth = time.time()
    patterns = pyfpgrowth.find_frequent_patterns(item_sets, support_threshold=int(support * len(item_sets)))
    
    # Generate association rules
    rules_fpgrowth = pyfpgrowth.generate_association_rules(patterns, confidence)
    end_time_fpgrowth = time.time()
    print(f"FP-Growth Time: {end_time_fpgrowth - start_time_fpgrowth} seconds")
    
    # Print FP-Growth generated rules
    print("FP-Growth Rules")
    for rule, metrics in rules_fpgrowth.items():
        print(f"Antecedent: {rule}, Consequent: {metrics[0]}, Confidence: {metrics[1]}")

# %%
# running amazon dataset with 0.4 support and 0.4 confidence
run_apriori()
# Out:
# choose dataset ( amazon, bestbuy, kmart, nike, generic):  amazon
# Enter minimum support:  0.4
# Enter minimum confidence:  0.4
# Brute-Force Time: 0.00033783912658691406 seconds
# Frequent item sets
# {1: {frozenset({' Android Programming: The Big Nerd Ranch'}), frozenset({' Java For Dummies'}), frozenset({'A Beginner’s Guide'}), frozenset({' Java: The Complete Reference'})}, 2: {frozenset({' Java For Dummies', 'A Beginner’s Guide'}), frozenset({'A Beginner’s Guide', ' Java: The Complete Reference'}), frozenset({' Java For Dummies', ' Java: The Complete Reference'})}, 3: {frozenset({' Java For Dummies', 'A Beginner’s Guide', ' Java: The Complete Reference'})}}
# Associated Rules:
# [{'A Beginner’s Guide'}, {' Java For Dummies'}, 0.8181818181818182]
# [{'A Beginner’s Guide'}, {' Java: The Complete Reference'}, 0.8181818181818182]
# [{'A Beginner’s Guide'}, {' Java For Dummies', ' Java: The Complete Reference'}, 0.8181818181818182]
# [{' Java For Dummies'}, {'A Beginner’s Guide'}, 0.9]
# [{' Java For Dummies'}, {' Java: The Complete Reference'}, 0.9]
# [{' Java For Dummies'}, {'A Beginner’s Guide', ' Java: The Complete Reference'}, 0.9]
# [{' Java: The Complete Reference'}, {'A Beginner’s Guide'}, 1.0]
# [{' Java: The Complete Reference'}, {' Java For Dummies'}, 1.0]
# [{' Java: The Complete Reference'}, {' Java For Dummies', 'A Beginner’s Guide'}, 1.0]
# [{' Java For Dummies', 'A Beginner’s Guide'}, {' Java: The Complete Reference'}, 1.0]
# [{' Java For Dummies', ' Java: The Complete Reference'}, {'A Beginner’s Guide'}, 1.0]
# [{'A Beginner’s Guide', ' Java: The Complete Reference'}, {' Java For Dummies'}, 1.0]
# --Applying Apriori Algo from a python library--
# Apriori Time: 0.009071111679077148 seconds
# Apriori Rules
#                                           antecedents  \
# 0                                 ( Java For Dummies)
# 1                     ( Java: The Complete Reference)
# 2                                 ( Java For Dummies)
# 3                                (A Beginner’s Guide)
# 4                                (A Beginner’s Guide)
# 5                     ( Java: The Complete Reference)
# 6             ( Java For Dummies, A Beginner’s Guide)
# 7   ( Java For Dummies,  Java: The Complete Refere...
# 8   (A Beginner’s Guide,  Java: The Complete Refer...
# 9                                 ( Java For Dummies)
# 10                               (A Beginner’s Guide)
# 11                    ( Java: The Complete Reference)
#
#                                           consequents   support  confidence
# 0                     ( Java: The Complete Reference)  0.428571    0.900000
# 1                                 ( Java For Dummies)  0.428571    1.000000
# 2                                (A Beginner’s Guide)  0.428571    0.900000
# 3                                 ( Java For Dummies)  0.428571    0.818182
# 4                     ( Java: The Complete Reference)  0.428571    0.818182
# 5                                (A Beginner’s Guide)  0.428571    1.000000
# 6                     ( Java: The Complete Reference)  0.428571    1.000000
# 7                                (A Beginner’s Guide)  0.428571    1.000000
# 8                                 ( Java For Dummies)  0.428571    1.000000
# 9   (A Beginner’s Guide,  Java: The Complete Refer...  0.428571    0.900000
# 10  ( Java For Dummies,  Java: The Complete Refere...  0.428571    0.818182
# 11            ( Java For Dummies, A Beginner’s Guide)  0.428571    1.000000
# --Applying FP-Growth Algorith--
# FP-Growth Time: 0.0005009174346923828 seconds
# FP-Growth Rules
# Antecedent: (' Java For Dummies',), Consequent: ('A Beginner’s Guide',), Confidence: 0.9
# Antecedent: (' Java: The Complete Reference',), Consequent: (' Java For Dummies', 'A Beginner’s Guide'), Confidence: 1.0
# Antecedent: ('A Beginner’s Guide',), Consequent: (' Java For Dummies',), Confidence: 0.8181818181818182
# Antecedent: (' Java For Dummies', ' Java: The Complete Reference'), Consequent: ('A Beginner’s Guide',), Confidence: 1.0
# Antecedent: (' Java For Dummies', 'A Beginner’s Guide'), Consequent: (' Java: The Complete Reference',), Confidence: 1.0
# Antecedent: (' Java: The Complete Reference', 'A Beginner’s Guide'), Consequent: (' Java For Dummies',), Confidence: 1.0

# %%
# running amazon dataset with 0.3 support and 0.3 confidence
run_apriori()
# Out:
# choose dataset ( amazon, bestbuy, kmart, nike, generic):  amazon
# Enter minimum support:  0.3
# Enter minimum confidence:  0.3
# Brute-Force Time: 0.00025200843811035156 seconds
# Frequent item sets
# {1: {frozenset({' Android Programming: The Big Nerd Ranch'}), frozenset({' Java For Dummies'}), frozenset({'A Beginner’s Guide'}), frozenset({' Java: The Complete Reference'})}, 2: {frozenset({' Java For Dummies', 'A Beginner’s Guide'}), frozenset({'A Beginner’s Guide', ' Java: The Complete Reference'}), frozenset({' Java For Dummies', ' Java: The Complete Reference'})}, 3: {frozenset({' Java For Dummies', 'A Beginner’s Guide', ' Java: The Complete Reference'})}}
# Associated Rules:
# [{'A Beginner’s Guide'}, {' Java For Dummies'}, 0.8181818181818182]
# [{'A Beginner’s Guide'}, {' Java: The Complete Reference'}, 0.8181818181818182]
# [{'A Beginner’s Guide'}, {' Java For Dummies', ' Java: The Complete Reference'}, 0.8181818181818182]
# [{' Java For Dummies'}, {'A Beginner’s Guide'}, 0.9]
# [{' Java For Dummies'}, {' Java: The Complete Reference'}, 0.9]
# [{' Java For Dummies'}, {'A Beginner’s Guide', ' Java: The Complete Reference'}, 0.9]
# [{' Java: The Complete Reference'}, {'A Beginner’s Guide'}, 1.0]
# [{' Java: The Complete Reference'}, {' Java For Dummies'}, 1.0]
# [{' Java: The Complete Reference'}, {' Java For Dummies', 'A Beginner’s Guide'}, 1.0]
# [{' Java For Dummies', 'A Beginner’s Guide'}, {' Java: The Complete Reference'}, 1.0]
# [{' Java For Dummies', ' Java: The Complete Reference'}, {'A Beginner’s Guide'}, 1.0]
# [{'A Beginner’s Guide', ' Java: The Complete Reference'}, {' Java For Dummies'}, 1.0]
# --Applying Apriori Algo from a python library--
# Apriori Time: 0.0074880123138427734 seconds
# Apriori Rules
#                                           antecedents  \
# 0                                 ( Java For Dummies)
# 1                     ( Java: The Complete Reference)
# 2                                 ( Java For Dummies)
# 3                                (A Beginner’s Guide)
# 4                                (A Beginner’s Guide)
# 5                     ( Java: The Complete Reference)
# 6             ( Java For Dummies, A Beginner’s Guide)
# 7   ( Java For Dummies,  Java: The Complete Refere...
# 8   (A Beginner’s Guide,  Java: The Complete Refer...
# 9                                 ( Java For Dummies)
# 10                               (A Beginner’s Guide)
# 11                    ( Java: The Complete Reference)
#
#                                           consequents   support  confidence
# 0                     ( Java: The Complete Reference)  0.428571    0.900000
# 1                                 ( Java For Dummies)  0.428571    1.000000
# 2                                (A Beginner’s Guide)  0.428571    0.900000
# 3                                 ( Java For Dummies)  0.428571    0.818182
# 4                     ( Java: The Complete Reference)  0.428571    0.818182
# 5                                (A Beginner’s Guide)  0.428571    1.000000
# 6                     ( Java: The Complete Reference)  0.428571    1.000000
# 7                                (A Beginner’s Guide)  0.428571    1.000000
# 8                                 ( Java For Dummies)  0.428571    1.000000
# 9   (A Beginner’s Guide,  Java: The Complete Refer...  0.428571    0.900000
# 10  ( Java For Dummies,  Java: The Complete Refere...  0.428571    0.818182
# 11            ( Java For Dummies, A Beginner’s Guide)  0.428571    1.000000
# --Applying FP-Growth Algorith--
# FP-Growth Time: 0.0005428791046142578 seconds
# FP-Growth Rules
# Antecedent: (' Java For Dummies',), Consequent: ('A Beginner’s Guide',), Confidence: 0.9
# Antecedent: (' Java: The Complete Reference',), Consequent: (' Java For Dummies', 'A Beginner’s Guide'), Confidence: 1.0
# Antecedent: ('A Beginner’s Guide',), Consequent: (' Android Programming: The Big Nerd Ranch',), Confidence: 0.5454545454545454
# Antecedent: (' Java For Dummies', ' Java: The Complete Reference'), Consequent: ('A Beginner’s Guide',), Confidence: 1.0
# Antecedent: (' Java For Dummies', 'A Beginner’s Guide'), Consequent: (' Java: The Complete Reference',), Confidence: 1.0
# Antecedent: (' Java: The Complete Reference', 'A Beginner’s Guide'), Consequent: (' Java For Dummies',), Confidence: 1.0
# Antecedent: (' Android Programming: The Big Nerd Ranch',), Consequent: ('A Beginner’s Guide',), Confidence: 0.6

# %%
# running bestbuy dataset with 0.4 support and 0.4 confidence
run_apriori()
# Out:
# choose dataset ( amazon, bestbuy, kmart, nike, generic):  bestbuy
# Enter minimum support:  0.4
# Enter minimum confidence:  0.4
# Brute-Force Time: 0.0009181499481201172 seconds
# Frequent item sets
# {1: {frozenset({' Flash Drive'}), frozenset({' Speakers'}), frozenset({' External Hard-Drive'}), frozenset({' Printer'}), frozenset({' Lab Top Case'}), frozenset({' Anti-Virus'}), frozenset({' Microsoft Office'}), frozenset({'Digital Camera '})}, 2: {frozenset({' Speakers', ' Anti-Virus'}), frozenset({' Flash Drive', ' Printer'}), frozenset({' Speakers', ' Lab Top Case'}), frozenset({' Microsoft Office', ' Anti-Virus'}), frozenset({' Flash Drive', ' Lab Top Case'}), frozenset({' Flash Drive', ' Microsoft Office'}), frozenset({' Lab Top Case', ' External Hard-Drive'}), frozenset({' Anti-Virus', ' External Hard-Drive'}), frozenset({' Microsoft Office', ' Printer'}), frozenset({' Lab Top Case', ' Anti-Virus'}), frozenset({' Flash Drive', ' Anti-Virus'})}, 3: {frozenset({' Flash Drive', ' Microsoft Office', ' Anti-Virus'}), frozenset({' Lab Top Case', ' Anti-Virus', ' External Hard-Drive'}), frozenset({' Flash Drive', ' Microsoft Office', ' Printer'}), frozenset({' Flash Drive', ' Anti-Virus', ' Lab Top Case'})}}
# Associated Rules:
# [{' Anti-Virus'}, {' Speakers'}, 0.5714285714285714]
# [{' Lab Top Case'}, {' Speakers'}, 0.5714285714285714]
# [{' Anti-Virus'}, {' Microsoft Office'}, 0.5714285714285714]
# [{' Lab Top Case'}, {' External Hard-Drive'}, 0.5714285714285714]
# [{' Anti-Virus'}, {' Flash Drive', ' Microsoft Office'}, 0.5714285714285714]
# [{' Lab Top Case'}, {' Anti-Virus', ' External Hard-Drive'}, 0.5714285714285714]
# [{' Anti-Virus'}, {' Lab Top Case', ' External Hard-Drive'}, 0.5714285714285714]
# [{' Flash Drive'}, {' Microsoft Office', ' Anti-Virus'}, 0.6153846153846154]
# [{' Flash Drive'}, {' Microsoft Office', ' Printer'}, 0.6153846153846154]
# [{' Lab Top Case'}, {' Flash Drive'}, 0.6428571428571429]
# [{' Anti-Virus'}, {' External Hard-Drive'}, 0.6428571428571429]
# [{' Anti-Virus'}, {' Flash Drive', ' Lab Top Case'}, 0.6428571428571429]
# [{' Lab Top Case'}, {' Flash Drive', ' Anti-Virus'}, 0.6428571428571429]
# [{' Lab Top Case', ' Anti-Virus'}, {' External Hard-Drive'}, 0.6666666666666666]
# [{' Flash Drive'}, {' Printer'}, 0.6923076923076923]
# [{' Flash Drive'}, {' Lab Top Case'}, 0.6923076923076923]
# [{' Flash Drive'}, {' Lab Top Case', ' Anti-Virus'}, 0.6923076923076923]
# [{' Anti-Virus'}, {' Flash Drive'}, 0.7142857142857143]
# [{' Microsoft Office'}, {' Anti-Virus'}, 0.7272727272727273]
# [{' Microsoft Office'}, {' Printer'}, 0.7272727272727273]
# [{' Microsoft Office'}, {' Flash Drive', ' Anti-Virus'}, 0.7272727272727273]
# [{' Flash Drive', ' Microsoft Office'}, {' Anti-Virus'}, 0.7272727272727273]
# [{' Microsoft Office'}, {' Flash Drive', ' Printer'}, 0.7272727272727273]
# [{' Flash Drive', ' Microsoft Office'}, {' Printer'}, 0.7272727272727273]
# [{' Lab Top Case', ' Anti-Virus'}, {' Flash Drive'}, 0.75]
# [{' Flash Drive'}, {' Anti-Virus'}, 0.7692307692307693]
# [{' Speakers'}, {' Anti-Virus'}, 0.8]
# [{' Speakers'}, {' Lab Top Case'}, 0.8]
# [{' Flash Drive', ' Anti-Virus'}, {' Microsoft Office'}, 0.8]
# [{' Flash Drive'}, {' Microsoft Office'}, 0.8461538461538461]
# [{' Lab Top Case'}, {' Anti-Virus'}, 0.8571428571428571]
# [{' Anti-Virus'}, {' Lab Top Case'}, 0.8571428571428571]
# [{' External Hard-Drive'}, {' Lab Top Case'}, 0.8888888888888888]
# [{' Printer'}, {' Microsoft Office'}, 0.8888888888888888]
# [{' External Hard-Drive'}, {' Lab Top Case', ' Anti-Virus'}, 0.8888888888888888]
# [{' Anti-Virus', ' External Hard-Drive'}, {' Lab Top Case'}, 0.8888888888888888]
# [{' Printer'}, {' Flash Drive', ' Microsoft Office'}, 0.8888888888888888]
# [{' Flash Drive', ' Printer'}, {' Microsoft Office'}, 0.8888888888888888]
# [{' Flash Drive', ' Anti-Virus'}, {' Lab Top Case'}, 0.9]
# [{' Printer'}, {' Flash Drive'}, 1.0]
# [{' Microsoft Office'}, {' Flash Drive'}, 1.0]
# [{' External Hard-Drive'}, {' Anti-Virus'}, 1.0]
# [{' Microsoft Office', ' Anti-Virus'}, {' Flash Drive'}, 1.0]
# [{' Lab Top Case', ' External Hard-Drive'}, {' Anti-Virus'}, 1.0]
# [{' Microsoft Office', ' Printer'}, {' Flash Drive'}, 1.0]
# [{' Flash Drive', ' Lab Top Case'}, {' Anti-Virus'}, 1.0]
# --Applying Apriori Algo from a python library--
# Apriori Time: 0.008726119995117188 seconds
# Apriori Rules
#                               antecedents  \
# 0                           ( Anti-Virus)
# 1                  ( External Hard-Drive)
# 2                          ( Flash Drive)
# 3                           ( Anti-Virus)
# 4                         ( Lab Top Case)
# 5                           ( Anti-Virus)
# 6                     ( Microsoft Office)
# 7                           ( Anti-Virus)
# 8                             ( Speakers)
# 9                           ( Anti-Virus)
# 10                        ( Lab Top Case)
# 11                 ( External Hard-Drive)
# 12                         ( Flash Drive)
# 13                        ( Lab Top Case)
# 14                         ( Flash Drive)
# 15                    ( Microsoft Office)
# 16                         ( Flash Drive)
# 17                             ( Printer)
# 18                            ( Speakers)
# 19                        ( Lab Top Case)
# 20                    ( Microsoft Office)
# 21                             ( Printer)
# 22           ( Lab Top Case,  Anti-Virus)
# 23  ( Lab Top Case,  External Hard-Drive)
# 24    ( Anti-Virus,  External Hard-Drive)
# 25                        ( Lab Top Case)
# 26                          ( Anti-Virus)
# 27                 ( External Hard-Drive)
# 28            ( Flash Drive,  Anti-Virus)
# 29          ( Flash Drive,  Lab Top Case)
# 30           ( Lab Top Case,  Anti-Virus)
# 31                         ( Flash Drive)
# 32                          ( Anti-Virus)
# 33                        ( Lab Top Case)
# 34      ( Flash Drive,  Microsoft Office)
# 35            ( Flash Drive,  Anti-Virus)
# 36       ( Microsoft Office,  Anti-Virus)
# 37                         ( Flash Drive)
# 38                    ( Microsoft Office)
# 39                          ( Anti-Virus)
# 40      ( Flash Drive,  Microsoft Office)
# 41               ( Flash Drive,  Printer)
# 42          ( Microsoft Office,  Printer)
# 43                         ( Flash Drive)
# 44                    ( Microsoft Office)
# 45                             ( Printer)
#
#                               consequents  support  confidence
# 0                  ( External Hard-Drive)     0.45    0.642857
# 1                           ( Anti-Virus)     0.45    1.000000
# 2                           ( Anti-Virus)     0.50    0.769231
# 3                          ( Flash Drive)     0.50    0.714286
# 4                           ( Anti-Virus)     0.60    0.857143
# 5                         ( Lab Top Case)     0.60    0.857143
# 6                           ( Anti-Virus)     0.40    0.727273
# 7                     ( Microsoft Office)     0.40    0.571429
# 8                           ( Anti-Virus)     0.40    0.800000
# 9                             ( Speakers)     0.40    0.571429
# 10                 ( External Hard-Drive)     0.40    0.571429
# 11                        ( Lab Top Case)     0.40    0.888889
# 12                        ( Lab Top Case)     0.45    0.692308
# 13                         ( Flash Drive)     0.45    0.642857
# 14                    ( Microsoft Office)     0.55    0.846154
# 15                         ( Flash Drive)     0.55    1.000000
# 16                             ( Printer)     0.45    0.692308
# 17                         ( Flash Drive)     0.45    1.000000
# 18                        ( Lab Top Case)     0.40    0.800000
# 19                            ( Speakers)     0.40    0.571429
# 20                             ( Printer)     0.40    0.727273
# 21                    ( Microsoft Office)     0.40    0.888889
# 22                 ( External Hard-Drive)     0.40    0.666667
# 23                          ( Anti-Virus)     0.40    1.000000
# 24                        ( Lab Top Case)     0.40    0.888889
# 25    ( Anti-Virus,  External Hard-Drive)     0.40    0.571429
# 26  ( Lab Top Case,  External Hard-Drive)     0.40    0.571429
# 27           ( Lab Top Case,  Anti-Virus)     0.40    0.888889
# 28                        ( Lab Top Case)     0.45    0.900000
# 29                          ( Anti-Virus)     0.45    1.000000
# 30                         ( Flash Drive)     0.45    0.750000
# 31           ( Lab Top Case,  Anti-Virus)     0.45    0.692308
# 32          ( Flash Drive,  Lab Top Case)     0.45    0.642857
# 33            ( Flash Drive,  Anti-Virus)     0.45    0.642857
# 34                          ( Anti-Virus)     0.40    0.727273
# 35                    ( Microsoft Office)     0.40    0.800000
# 36                         ( Flash Drive)     0.40    1.000000
# 37       ( Microsoft Office,  Anti-Virus)     0.40    0.615385
# 38            ( Flash Drive,  Anti-Virus)     0.40    0.727273
# 39      ( Flash Drive,  Microsoft Office)     0.40    0.571429
# 40                             ( Printer)     0.40    0.727273
# 41                    ( Microsoft Office)     0.40    0.888889
# 42                         ( Flash Drive)     0.40    1.000000
# 43          ( Microsoft Office,  Printer)     0.40    0.615385
# 44               ( Flash Drive,  Printer)     0.40    0.727273
# 45      ( Flash Drive,  Microsoft Office)     0.40    0.888889
# --Applying FP-Growth Algorith--
# FP-Growth Time: 0.0007572174072265625 seconds
# FP-Growth Rules
# Antecedent: (' Microsoft Office',), Consequent: (' Anti-Virus', ' Flash Drive'), Confidence: 0.7272727272727273
# Antecedent: (' Printer',), Consequent: (' Flash Drive', ' Microsoft Office'), Confidence: 0.8888888888888888
# Antecedent: (' Flash Drive',), Consequent: (' Anti-Virus', ' Lab Top Case'), Confidence: 0.6923076923076923
# Antecedent: (' Flash Drive', ' Microsoft Office'), Consequent: (' Anti-Virus',), Confidence: 0.7272727272727273
# Antecedent: (' Flash Drive', ' Printer'), Consequent: (' Microsoft Office',), Confidence: 0.8888888888888888
# Antecedent: (' Microsoft Office', ' Printer'), Consequent: (' Flash Drive',), Confidence: 1.0
# Antecedent: (' External Hard-Drive',), Consequent: (' Anti-Virus', ' Lab Top Case'), Confidence: 0.8888888888888888
# Antecedent: (' Lab Top Case',), Consequent: (' Anti-Virus',), Confidence: 0.8571428571428571
# Antecedent: (' Anti-Virus',), Consequent: (' Lab Top Case',), Confidence: 0.8571428571428571
# Antecedent: (' Anti-Virus', ' External Hard-Drive'), Consequent: (' Lab Top Case',), Confidence: 0.8888888888888888
# Antecedent: (' Anti-Virus', ' Lab Top Case'), Consequent: (' Flash Drive',), Confidence: 0.75
# Antecedent: (' External Hard-Drive', ' Lab Top Case'), Consequent: (' Anti-Virus',), Confidence: 1.0
# Antecedent: (' Anti-Virus', ' Flash Drive'), Consequent: (' Lab Top Case',), Confidence: 0.9
# Antecedent: (' Anti-Virus', ' Microsoft Office'), Consequent: (' Flash Drive',), Confidence: 1.0
# Antecedent: (' Flash Drive', ' Lab Top Case'), Consequent: (' Anti-Virus',), Confidence: 1.0

# %%
# running kmart dataset with 0.4 support and 0.4 confidence
run_apriori()
# Out:
# choose dataset ( amazon, bestbuy, kmart, nike, generic):  kmart
# Enter minimum support:  0.4
# Enter minimum confidence:  0.4
# Brute-Force Time: 0.0002796649932861328 seconds
# Frequent item sets
# {1: {frozenset({' Kids Bedding'}), frozenset({'Decorative Pillows'}), frozenset({' Shams'}), frozenset({' Bed Skirts'})}, 2: {frozenset({' Kids Bedding', ' Bed Skirts'}), frozenset({' Bed Skirts', ' Shams'})}}
# Associated Rules:
# [{' Bed Skirts'}, {' Kids Bedding'}, 0.7272727272727273]
# [{' Bed Skirts'}, {' Shams'}, 0.7272727272727273]
# [{' Kids Bedding'}, {' Bed Skirts'}, 0.8]
# [{' Shams'}, {' Bed Skirts'}, 0.8]
# --Applying Apriori Algo from a python library--
# Apriori Time: 0.008028984069824219 seconds
# Apriori Rules
#        antecedents      consequents  support  confidence
# 0  ( Kids Bedding)    ( Bed Skirts)      0.4    0.800000
# 1    ( Bed Skirts)  ( Kids Bedding)      0.4    0.727273
# 2    ( Bed Skirts)         ( Shams)      0.4    0.727273
# 3         ( Shams)    ( Bed Skirts)      0.4    0.800000
# --Applying FP-Growth Algorith--
# FP-Growth Time: 0.00044798851013183594 seconds
# FP-Growth Rules
# Antecedent: (' Bed Skirts',), Consequent: (' Shams',), Confidence: 0.7272727272727273
# Antecedent: (' Kids Bedding',), Consequent: (' Bed Skirts',), Confidence: 0.8
# Antecedent: (' Shams',), Consequent: (' Bed Skirts',), Confidence: 0.8

# %%
# running nike dataset with 0.4 support and 0.4 confidence
run_apriori()
# Out:
# choose dataset ( amazon, bestbuy, kmart, nike, generic):  nike
# Enter minimum support:  0.4
# Enter minimum confidence:  0.4
# Brute-Force Time: 0.0006840229034423828 seconds
# Frequent item sets
# {1: {frozenset({' Modern Pants'}), frozenset({' Sweatshirts'}), frozenset({' Socks'}), frozenset({' Rash Guard'}), frozenset({'Running Shoe'}), frozenset({' Tech Pants'}), frozenset({' Dry Fit V-Nick'})}, 2: {frozenset({' Sweatshirts', ' Modern Pants'}), frozenset({' Socks', 'Running Shoe'}), frozenset({' Modern Pants', 'Running Shoe'}), frozenset({' Tech Pants', ' Rash Guard'}), frozenset({' Sweatshirts', ' Socks'}), frozenset({' Sweatshirts', 'Running Shoe'}), frozenset({' Socks', ' Modern Pants'}), frozenset({' Rash Guard', ' Dry Fit V-Nick'})}, 3: {frozenset({' Socks', ' Modern Pants', 'Running Shoe'}), frozenset({' Socks', 'Running Shoe', ' Sweatshirts'}), frozenset({' Sweatshirts', ' Socks', ' Modern Pants'}), frozenset({' Sweatshirts', ' Modern Pants', 'Running Shoe'})}, 4: {frozenset({' Socks', ' Modern Pants', 'Running Shoe', ' Sweatshirts'})}}
# Associated Rules:
# [{'Running Shoe'}, {' Socks', ' Modern Pants'}, 0.5714285714285714]
# [{'Running Shoe'}, {' Socks', ' Modern Pants', ' Sweatshirts'}, 0.5714285714285714]
# [{' Sweatshirts'}, {' Socks', ' Modern Pants'}, 0.6153846153846154]
# [{' Sweatshirts'}, {' Socks', ' Modern Pants', 'Running Shoe'}, 0.6153846153846154]
# [{'Running Shoe'}, {' Modern Pants'}, 0.6428571428571429]
# [{'Running Shoe'}, {' Sweatshirts', ' Modern Pants'}, 0.6428571428571429]
# [{' Socks'}, {' Modern Pants'}, 0.6666666666666666]
# [{' Rash Guard'}, {' Dry Fit V-Nick'}, 0.6666666666666666]
# [{' Socks'}, {' Modern Pants', 'Running Shoe'}, 0.6666666666666666]
# [{' Socks'}, {' Sweatshirts', ' Modern Pants'}, 0.6666666666666666]
# [{' Socks'}, {' Sweatshirts', ' Modern Pants', 'Running Shoe'}, 0.6666666666666666]
# [{' Sweatshirts'}, {' Modern Pants', 'Running Shoe'}, 0.6923076923076923]
# [{'Running Shoe'}, {' Socks', ' Sweatshirts'}, 0.7142857142857143]
# [{' Socks', 'Running Shoe'}, {' Modern Pants'}, 0.7272727272727273]
# [{' Sweatshirts', ' Socks'}, {' Modern Pants'}, 0.7272727272727273]
# [{' Socks', 'Running Shoe'}, {' Sweatshirts', ' Modern Pants'}, 0.7272727272727273]
# [{' Socks', ' Sweatshirts'}, {' Modern Pants', 'Running Shoe'}, 0.7272727272727273]
# [{' Sweatshirts', 'Running Shoe'}, {' Socks', ' Modern Pants'}, 0.7272727272727273]
# [{' Rash Guard'}, {' Tech Pants'}, 0.75]
# [{' Sweatshirts'}, {' Modern Pants'}, 0.7692307692307693]
# [{' Sweatshirts'}, {' Socks', 'Running Shoe'}, 0.7692307692307693]
# [{'Running Shoe'}, {' Socks'}, 0.7857142857142857]
# [{'Running Shoe'}, {' Sweatshirts'}, 0.7857142857142857]
# [{' Modern Pants'}, {' Socks'}, 0.8]
# [{' Modern Pants'}, {' Socks', 'Running Shoe'}, 0.8]
# [{' Modern Pants'}, {' Sweatshirts', ' Socks'}, 0.8]
# [{' Sweatshirts', ' Modern Pants'}, {' Socks'}, 0.8]
# [{' Modern Pants'}, {' Socks', 'Running Shoe', ' Sweatshirts'}, 0.8]
# [{' Sweatshirts', ' Modern Pants'}, {' Socks', 'Running Shoe'}, 0.8]
# [{' Socks', 'Running Shoe', ' Sweatshirts'}, {' Modern Pants'}, 0.8]
# [{' Sweatshirts', 'Running Shoe'}, {' Modern Pants'}, 0.8181818181818182]
# [{' Socks'}, {' Sweatshirts', 'Running Shoe'}, 0.8333333333333334]
# [{' Sweatshirts'}, {' Socks'}, 0.8461538461538461]
# [{' Sweatshirts'}, {'Running Shoe'}, 0.8461538461538461]
# [{' Modern Pants', 'Running Shoe'}, {' Socks'}, 0.8888888888888888]
# [{' Modern Pants', 'Running Shoe'}, {' Socks', ' Sweatshirts'}, 0.8888888888888888]
# [{' Sweatshirts', ' Modern Pants', 'Running Shoe'}, {' Socks'}, 0.8888888888888888]
# [{' Modern Pants'}, {'Running Shoe'}, 0.9]
# [{' Modern Pants'}, {' Sweatshirts', 'Running Shoe'}, 0.9]
# [{' Sweatshirts', ' Modern Pants'}, {'Running Shoe'}, 0.9]
# [{' Socks', 'Running Shoe'}, {' Sweatshirts'}, 0.9090909090909091]
# [{' Socks', ' Sweatshirts'}, {'Running Shoe'}, 0.9090909090909091]
# [{' Sweatshirts', 'Running Shoe'}, {' Socks'}, 0.9090909090909091]
# [{' Socks'}, {'Running Shoe'}, 0.9166666666666666]
# [{' Socks'}, {' Sweatshirts'}, 0.9166666666666666]
# [{' Modern Pants'}, {' Sweatshirts'}, 1.0]
# [{' Tech Pants'}, {' Rash Guard'}, 1.0]
# [{' Dry Fit V-Nick'}, {' Rash Guard'}, 1.0]
# [{' Socks', ' Modern Pants'}, {'Running Shoe'}, 1.0]
# [{' Socks', ' Modern Pants'}, {' Sweatshirts'}, 1.0]
# [{' Modern Pants', 'Running Shoe'}, {' Sweatshirts'}, 1.0]
# [{' Socks', ' Modern Pants'}, {' Sweatshirts', 'Running Shoe'}, 1.0]
# [{' Socks', ' Modern Pants', 'Running Shoe'}, {' Sweatshirts'}, 1.0]
# [{' Socks', ' Modern Pants', ' Sweatshirts'}, {'Running Shoe'}, 1.0]
# --Applying Apriori Algo from a python library--
# Apriori Time: 0.011184930801391602 seconds
# Apriori Rules
#                                     antecedents  \
# 0                                 ( Rash Guard)
# 1                             ( Dry Fit V-Nick)
# 2                                      ( Socks)
# 3                               ( Modern Pants)
# 4                                ( Sweatshirts)
# 5                               ( Modern Pants)
# 6                               ( Modern Pants)
# 7                                (Running Shoe)
# 8                                 ( Tech Pants)
# 9                                 ( Rash Guard)
# 10                                     ( Socks)
# 11                               ( Sweatshirts)
# 12                                     ( Socks)
# 13                               (Running Shoe)
# 14                               ( Sweatshirts)
# 15                               (Running Shoe)
# 16                      ( Socks,  Modern Pants)
# 17                       ( Socks,  Sweatshirts)
# 18                ( Sweatshirts,  Modern Pants)
# 19                                     ( Socks)
# 20                              ( Modern Pants)
# 21                               ( Sweatshirts)
# 22                      ( Socks,  Modern Pants)
# 23                       ( Socks, Running Shoe)
# 24                ( Modern Pants, Running Shoe)
# 25                                     ( Socks)
# 26                              ( Modern Pants)
# 27                               (Running Shoe)
# 28                ( Sweatshirts,  Modern Pants)
# 29                 ( Sweatshirts, Running Shoe)
# 30                ( Modern Pants, Running Shoe)
# 31                               ( Sweatshirts)
# 32                              ( Modern Pants)
# 33                               (Running Shoe)
# 34                       ( Socks, Running Shoe)
# 35                       ( Socks,  Sweatshirts)
# 36                 ( Sweatshirts, Running Shoe)
# 37                                     ( Socks)
# 38                               (Running Shoe)
# 39                               ( Sweatshirts)
# 40        ( Socks,  Modern Pants, Running Shoe)
# 41        ( Socks,  Modern Pants,  Sweatshirts)
# 42         ( Socks, Running Shoe,  Sweatshirts)
# 43  ( Sweatshirts,  Modern Pants, Running Shoe)
# 44                      ( Socks,  Modern Pants)
# 45                       ( Socks, Running Shoe)
# 46                       ( Socks,  Sweatshirts)
# 47                ( Modern Pants, Running Shoe)
# 48                ( Sweatshirts,  Modern Pants)
# 49                 ( Sweatshirts, Running Shoe)
# 50                                     ( Socks)
# 51                              ( Modern Pants)
# 52                               (Running Shoe)
# 53                               ( Sweatshirts)
#
#                                     consequents  support  confidence
# 0                             ( Dry Fit V-Nick)     0.40    0.666667
# 1                                 ( Rash Guard)     0.40    1.000000
# 2                               ( Modern Pants)     0.40    0.666667
# 3                                      ( Socks)     0.40    0.800000
# 4                               ( Modern Pants)     0.50    0.769231
# 5                                ( Sweatshirts)     0.50    1.000000
# 6                                (Running Shoe)     0.45    0.900000
# 7                               ( Modern Pants)     0.45    0.642857
# 8                                 ( Rash Guard)     0.45    1.000000
# 9                                 ( Tech Pants)     0.45    0.750000
# 10                               ( Sweatshirts)     0.55    0.916667
# 11                                     ( Socks)     0.55    0.846154
# 12                               (Running Shoe)     0.55    0.916667
# 13                                     ( Socks)     0.55    0.785714
# 14                               (Running Shoe)     0.55    0.846154
# 15                               ( Sweatshirts)     0.55    0.785714
# 16                               ( Sweatshirts)     0.40    1.000000
# 17                              ( Modern Pants)     0.40    0.727273
# 18                                     ( Socks)     0.40    0.800000
# 19                ( Sweatshirts,  Modern Pants)     0.40    0.666667
# 20                       ( Socks,  Sweatshirts)     0.40    0.800000
# 21                      ( Socks,  Modern Pants)     0.40    0.615385
# 22                               (Running Shoe)     0.40    1.000000
# 23                              ( Modern Pants)     0.40    0.727273
# 24                                     ( Socks)     0.40    0.888889
# 25                ( Modern Pants, Running Shoe)     0.40    0.666667
# 26                       ( Socks, Running Shoe)     0.40    0.800000
# 27                      ( Socks,  Modern Pants)     0.40    0.571429
# 28                               (Running Shoe)     0.45    0.900000
# 29                              ( Modern Pants)     0.45    0.818182
# 30                               ( Sweatshirts)     0.45    1.000000
# 31                ( Modern Pants, Running Shoe)     0.45    0.692308
# 32                 ( Sweatshirts, Running Shoe)     0.45    0.900000
# 33                ( Sweatshirts,  Modern Pants)     0.45    0.642857
# 34                               ( Sweatshirts)     0.50    0.909091
# 35                               (Running Shoe)     0.50    0.909091
# 36                                     ( Socks)     0.50    0.909091
# 37                 ( Sweatshirts, Running Shoe)     0.50    0.833333
# 38                       ( Socks,  Sweatshirts)     0.50    0.714286
# 39                       ( Socks, Running Shoe)     0.50    0.769231
# 40                               ( Sweatshirts)     0.40    1.000000
# 41                               (Running Shoe)     0.40    1.000000
# 42                              ( Modern Pants)     0.40    0.800000
# 43                                     ( Socks)     0.40    0.888889
# 44                 ( Sweatshirts, Running Shoe)     0.40    1.000000
# 45                ( Sweatshirts,  Modern Pants)     0.40    0.727273
# 46                ( Modern Pants, Running Shoe)     0.40    0.727273
# 47                       ( Socks,  Sweatshirts)     0.40    0.888889
# 48                       ( Socks, Running Shoe)     0.40    0.800000
# 49                      ( Socks,  Modern Pants)     0.40    0.727273
# 50  ( Sweatshirts,  Modern Pants, Running Shoe)     0.40    0.666667
# 51         ( Socks, Running Shoe,  Sweatshirts)     0.40    0.800000
# 52        ( Socks,  Modern Pants,  Sweatshirts)     0.40    0.571429
# 53        ( Socks,  Modern Pants, Running Shoe)     0.40    0.615385
# --Applying FP-Growth Algorith--
# FP-Growth Time: 0.0007822513580322266 seconds
# FP-Growth Rules
# Antecedent: (' Dry Fit V-Nick',), Consequent: (' Rash Guard',), Confidence: 1.0
# Antecedent: (' Rash Guard',), Consequent: (' Tech Pants',), Confidence: 0.75
# Antecedent: (' Tech Pants',), Consequent: (' Rash Guard',), Confidence: 1.0
# Antecedent: (' Modern Pants',), Consequent: (' Socks', ' Sweatshirts', 'Running Shoe'), Confidence: 0.8
# Antecedent: (' Sweatshirts',), Consequent: ('Running Shoe',), Confidence: 0.8461538461538461
# Antecedent: ('Running Shoe',), Consequent: (' Sweatshirts',), Confidence: 0.7857142857142857
# Antecedent: (' Modern Pants', ' Socks'), Consequent: (' Sweatshirts', 'Running Shoe'), Confidence: 1.0
# Antecedent: (' Modern Pants', ' Sweatshirts'), Consequent: (' Socks', 'Running Shoe'), Confidence: 0.8
# Antecedent: (' Socks', ' Sweatshirts'), Consequent: ('Running Shoe',), Confidence: 0.9090909090909091
# Antecedent: (' Modern Pants', 'Running Shoe'), Consequent: (' Socks', ' Sweatshirts'), Confidence: 0.8888888888888888
# Antecedent: (' Socks', 'Running Shoe'), Consequent: (' Sweatshirts',), Confidence: 0.9090909090909091
# Antecedent: (' Sweatshirts', 'Running Shoe'), Consequent: (' Socks',), Confidence: 0.9090909090909091
# Antecedent: (' Modern Pants', ' Socks', ' Sweatshirts'), Consequent: ('Running Shoe',), Confidence: 1.0
# Antecedent: (' Modern Pants', ' Socks', 'Running Shoe'), Consequent: (' Sweatshirts',), Confidence: 1.0
# Antecedent: (' Modern Pants', ' Sweatshirts', 'Running Shoe'), Consequent: (' Socks',), Confidence: 0.8888888888888888
# Antecedent: (' Socks', ' Sweatshirts', 'Running Shoe'), Consequent: (' Modern Pants',), Confidence: 0.8

# %%
# running generic dataset with 0.3 support and 0.3 confidence
run_apriori()
# Out:
# choose dataset ( amazon, bestbuy, kmart, nike, generic):  generic
# Enter minimum support:  0.3
# Enter minimum confidence:  0.3
# Brute-Force Time: 0.00040912628173828125 seconds
# Frequent item sets
# {1: {frozenset({'A'}), frozenset({'E'}), frozenset({'D'}), frozenset({'H'}), frozenset({'C'}), frozenset({'G'}), frozenset({'B'}), frozenset({'F'})}, 2: {frozenset({'A', 'E'})}}
# Associated Rules:
# [{'A'}, {'E'}, 0.5454545454545454]
# [{'E'}, {'A'}, 0.6666666666666666]
# --Applying Apriori Algo from a python library--
# Apriori Time: 0.01174473762512207 seconds
# Apriori Rules
#   antecedents consequents  support  confidence
# 0         (A)         (E)      0.3    0.545455
# 1         (E)         (A)      0.3    0.666667
# --Applying FP-Growth Algorith--
# FP-Growth Time: 0.0006399154663085938 seconds
# FP-Growth Rules
# Antecedent: ('A',), Consequent: ('E',), Confidence: 0.5454545454545454
# Antecedent: ('E',), Consequent: ('A',), Confidence: 0.6666666666666666
